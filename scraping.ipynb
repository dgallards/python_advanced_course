# %% [markdown]
# # Web scraping con Python
#
# Web scraping es una técnica utilizada para extraer información de sitios web. Se utiliza para recopilar datos de sitios web y luego analizarlos para obtener información útil. En Python, se pueden usar diversas librerías para realizar web scraping, como Beautiful Soup..
#
# ## Qué es BeautifulSoup
#
# Beautiful Soup es una librería de Python diseñada para facilitar el análisis y la extracción de datos de sitios web. Permite navegar, buscar y modificar el árbol de elementos HTML o XML de una página web de manera sencilla. Con Beautiful Soup, se pueden seleccionar y extraer fácilmente los datos que se necesitan de una página web, lo que lo hace una herramienta ideal para el web scraping.
#
# ## Instalación
#
# Para utilizar BeautifulSoup, necesitaremos su biblioteca llamada beautifulsoup4. Para instalarla podemos ejecutar esta línea
#
# `$ pip install beautifulsoup4`
#
# Si aparece un error, podríamos ejecutar
#
# `$ pip install --trusted-host pypi.org --trusted-host files.pythonhosted.org beautifulsoup4`
#
# o bien:
#
# `$ pip install --user --trusted-host pypi.org --trusted-host files.pythonhosted.org beautifulsoup4`
#
#
#
# Comprobamos:

# %%
html_doc = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

from bs4 import BeautifulSoup
soup = BeautifulSoup(html_doc, 'html.parser')

print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %% [markdown]
# Podemos utilizar métodos de búsqueda de Beautiful Soup, como find() y find_all() para buscar y extraer información específica de la página web. También se pueden utilizar selectores de CSS y expresiones regulares para buscar elementos en el HTML.
#
# Por ejemplo:

# %%
title_tag = soup.find('title')
title = title_tag.get_text()
print(title)
# Out:
# The Dormouse's story

# %% [markdown]
# Para encontrar todos los elementos de una clase determinada en Beautiful Soup, se puede utilizar el método find_all() y pasar como argumento el atributo class con el nombre de la clase deseada.
#
# Por ejemplo, si desea encontrar todos los elementos a con la clase "sister" en una página HTML, puede hacerlo de la siguiente manera:

# %%
elements = soup.find_all( "a" , class_='sister')

print(elements)
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>, <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>, <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %% [markdown]
# Para encontrar todos los elementos cuyas clases comienzan con un determinado string, puedes usar el método find_all() con una expresión regular como valor del atributo class_.
# Esto es particularmente útil cuando

# %%
import re

elements = soup.find_all('a', class_=re.compile("^sis"))

print(elements)
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>, <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>, <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
import re

elements = soup.select('a', class_=re.compile("^sis"))

print(elements)
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>, <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>, <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %% [markdown]
# Vamos a navegar por este archivo HTML antes de continuar con los ejemplos:

# %%
from bs4 import BeautifulSoup
with open("resources/example_html.html","r",encoding="utf-8") as html:
    soup = BeautifulSoup(html, 'html.parser')
    print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Ejemplo de web scraping
#   </title>
#   <style>
#    .container {
#       width: 80%;
#       margin: 0 auto;
#     }
#     .title {
#       font-size: 36px;
#       font-weight: bold;
#       text-align: center;
#     }
#     .subtitle {
#       font-size: 24px;
#       text-align: center;
#     }
#     .card {
#       width: 30%;
#       float: left;
#       margin: 1%;
#       padding: 2%;
#       box-sizing: border-box;
#     }
#     .card img {
#       width: 100%;
#     }
#     .card h3 {
#       font-size: 18px;
#       margin-top: 10px;
#     }
#     .card p {
#       font-size: 14px;
#       margin-top: 5px;
#       line-height: 1.5;
#     }
#     .clearfix {
#       clear: both;
#     }
#   </style>
#  </head>
#  <body>
#   <div class="container">
#    <div class="header">
#     <h1 class="title">
#      Título principal
#     </h1>
#     <h2 class="subtitle">
#      Subtítulo
#     </h2>
#    </div>
#    <div class="card-container">
#     <div class="card">
#      <img alt="Imagen 1" src="https://via.placeholder.com/151"/>
#      <div class="card-body">
#       <h3 class="card-title">
#        Título de la tarjeta 1
#       </h3>
#       <p class="card-text">
#        Contenido de la tarjeta 1
#       </p>
#       <div class="card-footer">
#        <a class="card-link" href="#">
#         Link 1
#        </a>
#        <a class="card-link" href="#">
#         Link 2
#        </a>
#       </div>
#      </div>
#     </div>
#     <div class="card">
#      <img alt="Imagen 2" src="https://via.placeholder.com/152"/>
#      <div class="card-body">
#       <h3 class="card-title">
#        Título de la tarjeta 2
#       </h3>
#       <p class="card-text">
#        Contenido de la tarjeta 2
#       </p>
#       <div class="card-footer">
#        <a class="card-link" href="#">
#         Link 1
#        </a>
#        <a class="card-link" href="#">
#         Link 2
#        </a>
#       </div>
#      </div>
#     </div>
#     <div class="card">
#      <img alt="Imagen 3" src="https://via.placeholder.com/153"/>
#      <div class="card-body">
#       <h3 class="card-title">
#        Título de la tarjeta 3
#       </h3>
#       <p class="card-text">
#        Contenido de la tarjeta 3
#       </p>
#       <div class="card-footer">
#        <a class="card-link" href="#">
#         Link 1
#        </a>
#        <a class="card-link" href="#">
#         Link 2
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#  </body>
# </html>

# %% [markdown]
# Para realizar peticiones a URLs utilizamos la biblioteca requests y selenium.
#
# Para utilizarla, necesitaremos sus bibliotecas. Para instalarlas podemos ejecutar esta línea
#
# `$ pip install requests`
#
# `$ pip install selenium`
#
# Si aparece un error, podríamos ejecutar
#
# `$ pip install --trusted-host pypi.org --trusted-host files.pythonhosted.org requests`
#
# `$ pip install --trusted-host pypi.org --trusted-host files.pythonhosted.org selenium`
#
# o bien:
#
# `$ pip install --user --trusted-host pypi.org --trusted-host files.pythonhosted.org requests`
#
# `$ pip install --trusted-host pypi.org --trusted-host files.pythonhosted.org selenium`
#
# Lo probamos:

# %%
import requests

from bs4 import BeautifulSoup

url = 'http://localhost:8888/'
response = requests.get(url)
html = response.content

soup = BeautifulSoup(html, 'html.parser')

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <link href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" rel="stylesheet"/>
#   <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.3.1/jquery.min.js">
#   </script>
#   <script src="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/js/bootstrap.min.js">
#   </script>
#  </head>
#  <body>
#   <div class="container">
#    <div class="row">
#     <div class="col-xs-3">
#      <img alt="Logo" class="img-responsive" src="/resources/business-logo.jpg" style="width:50%;"/>
#     </div>
#     <div class="col-xs-6 text-center">
#      <h1>
#       Compracoches.net
#      </h1>
#     </div>
#    </div>
#   </div>
#   <nav class="navbar navbar-default">
#    <div class="container-fluid">
#     <div class="navbar-header">
#      <a class="navbar-brand" href="">
#       Inicio
#      </a>
#      <a class="navbar-brand" href="/html/about.html">
#       Sobre nosotros
#      </a>
#     </div>
#    </div>
#   </nav>
#   <div class="container">
#    <div class="row">
#     <div class="col-xs-12 text-center">
#      <form method="post">
#       <div class="form-group">
#        <input class="form-control" name="searchterm" placeholder="Search" required="" type="text"/>
#       </div>
#       <button class="btn btn-default" type="submit">
#        Submit
#       </button>
#      </form>
#      <div class="col-xs-12 text-center">
#      </div>
#     </div>
#    </div>
#   </div>
#  </body>
# </html>

# %% [markdown]
# ## Buscando información específica
#
# Ya hemos visto como hacer una busqueda y encontrar secciones especificas de una web. Sin embargo, cómo lo ponemos en práctica?
#
# Muchos sitios web requieren Javascript o el contenido se carga dinamicamente usando JavaScript, por lo que requests no será suficiente. Usaremos Selenium.
#
# Para ello debemos investigar como se realizan las búsquedas en diferentes sitios web, por ejemplo:

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from time import sleep


url = 'https://www.printables.com/es/search/models?q=iphone'


options = webdriver.ChromeOptions()
options.add_argument('--headless')
driver = webdriver.Chrome(chrome_options=options)
driver.get(url)
sleep(5)
html = driver.page_source

soup = BeautifulSoup(html, 'html.parser')

with open("page.html", "w", encoding="utf-8") as f:
    f.write(soup.prettify())
# Out:
# C:\Users\diego\AppData\Local\Temp\ipykernel_9656\42079887.py:13: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(chrome_options=options)

# %% [markdown]
# Una vez tengamos acceso a la web y sus elementos, podremos navegar por ellos y seleccionarlos

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from time import sleep

url = 'https://www.printables.com/es/search/models?q='+'iphone'

options = webdriver.ChromeOptions()
options.add_argument('--headless')
driver = webdriver.Chrome(chrome_options=options)
driver.get(url)
sleep(5)
html = driver.page_source

soup = BeautifulSoup(html, 'html.parser')

items = soup.find_all("div",class_="result-item")

for item in items:
    itemName = item.find("a", class_="link clamp-two-lines")
    print(itemName.text)
    print('https://www.printables.com'+itemName['href'])
    itemImg = item.find("div",class_="card")
    itemImg = itemImg.find('img')
    print(itemImg['src'])
# Out:
# C:\Users\diego\AppData\Local\Temp\ipykernel_9656\663541151.py:11: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(chrome_options=options)
#  iPhone Stand / iPhone Holder
# https://www.printables.com/es/model/107744-iphone-stand-iphone-holder
# https://media.printables.com/media/prints/107744/images/1070284_8348be92-9548-46b1-b781-7d62618cc3f6/thumbs/cover/320x240/jpg/img_3541.webp
#  iPhone 12 Dummy Models (iPhone 12 Mini, iPhone 12, iPhone 12 Pro, iPhone 12 Pro Max)
# https://www.printables.com/es/model/43469-iphone-12-dummy-models-iphone-12-mini-iphone-12-ip
# https://media.printables.com/media/prints/43469/images/432319_04ac6b50-4cdc-4bfc-8c14-2c260dd95de9/thumbs/cover/320x240/jpg/img_2897.webp
#  iPhone Stand
# https://www.printables.com/es/model/176650-iphone-stand
# https://media.printables.com/media/prints/176650/images/1657093_11a614e4-726b-414a-abd1-5c2222f415c5/thumbs/cover/320x240/jpg/20220422-dscf0619.webp
#  iPhone SE (2020,2022) / iPhone 8
# https://www.printables.com/es/model/275162-iphone-se-20202022-iphone-8
# https://media.printables.com/media/prints/275162/images/2444860_c457303b-1272-4f81-9bb9-cc0854cfba9d/thumbs/cover/320x240/jpg/img-7881.webp
#  IPHONE STAND
# https://www.printables.com/es/model/99335-iphone-stand
# https://media.printables.com/media/prints/99335/images/1004069_b7da6156-8ec0-4ba2-be99-6aff7202288a/thumbs/cover/320x240/png/render.webp
#  iPhone Stand
# https://www.printables.com/es/model/157404-iphone-stand
# https://media.printables.com/media/prints/157404/images/1471242_60e3d035-8293-4d12-8ea6-f5d24677585f/thumbs/cover/320x240/jpg/large_display_img_6522_157404.webp
#  iPhone Stand
# https://www.printables.com/es/model/128413-iphone-stand
# https://media.printables.com/media/prints/128413/images/3124033_54161f92-8f5a-4040-932c-25066b47e6cd/thumbs/cover/320x240/jpeg/3ffd9c5b-649d-4000-a733-e2c18d994950.webp
#  İphone 13
# https://www.printables.com/es/model/267329-iphone-13
# https://media.printables.com/media/prints/267329/images/2461315_f9566c49-02fb-4b83-a937-b7196dd7f6bc/thumbs/cover/320x240/png/ekran-goruntusu-26.webp
#  iPhone 5 iPhone SE Case
# https://www.printables.com/es/model/182712-iphone-5-iphone-se-case
# https://media.printables.com/media/prints/182712/images/1705372_9fd4b9f3-881e-4df1-b619-3753cb42921d/thumbs/cover/320x240/jpg/50fd1ce91b4c34660fb04f70e6ed2bb0_display_large_18.webp
#  iPhone holder
# https://www.printables.com/es/model/253385-iphone-holder
# https://media.printables.com/media/prints/253385/images/2272985_6959e024-c398-4f8a-9823-0227925bb0b5/thumbs/cover/320x240/jpeg/01833c52-dcca-418b-bd48-6427c5f9dc2c.webp
#  iPhone Holder
# https://www.printables.com/es/model/267829-iphone-holder
# https://media.printables.com/media/prints/267829/images/2383123_d96c9bbc-dd9f-4ac3-934b-40bc071e49f1/thumbs/cover/320x240/jpg/tempimageviq6al.webp
#  iPhone dock
# https://www.printables.com/es/model/131718-iphone-dock
# https://media.printables.com/media/prints/131718/images/1261468_e827fc7f-b341-4106-b014-a0c7cd185e39/thumbs/cover/320x240/jpeg/img_0130.webp
#  Iphone Vault
# https://www.printables.com/es/model/99974-iphone-vault
# https://media.printables.com/media/prints/99974/images/1008452_91fe30c5-a4de-463e-88dd-9a880599f8a9/thumbs/cover/320x240/jpeg/large_display_iphone_vault_-_1_of_1_99974.webp
#  iPhone XR Flexible Case (iPhone 12 wannabe)
# https://www.printables.com/es/model/75019-iphone-xr-flexible-case-iphone-12-wannabe
# https://media.printables.com/media/prints/75019/images/811456_90c1f2d1-1706-4058-9ec7-c99117330b8d/thumbs/cover/320x240/jpg/case.webp
#  Iphone hand
# https://www.printables.com/es/model/106635-iphone-hand
# https://media.printables.com/media/prints/106635/images/1062553_4039d36c-47a8-40f0-9395-6740f83a8f5f/thumbs/cover/320x240/jpeg/whatsapp-image-2021-12-14-at-085802.webp
#  iPhone Phone
# https://www.printables.com/es/model/72100-iphone-phone
# https://media.printables.com/media/prints/72100/images/782261_04955049-971e-41b9-abab-4f8b030c7a20/thumbs/cover/320x240/jpg/iphone_phone_sound_2012-02-29_11275900000_display.webp
#  iPhone 13
# https://www.printables.com/es/model/359469-iphone-13
# https://media.printables.com/media/prints/359469/images/3042948_1b4a833c-b972-4134-adba-7066310a9939/thumbs/cover/320x240/jpg/img20230105122939.webp
#  iphone xr
# https://www.printables.com/es/model/367696-iphone-xr
# https://media.printables.com/media/prints/367696/images/3102329_fe9ef74e-b676-4f8a-a803-481398bc45f6/thumbs/cover/320x240/jpg/madeinhell-fundaxr.webp
#  iphone base
# https://www.printables.com/es/model/296394-iphone-base
# https://media.printables.com/media/prints/296394/images/2598368_df26377b-158e-41c4-b3b6-6d92d3f8b53d/thumbs/cover/320x240/jpg/1.webp
#  iPhone Holder
# https://www.printables.com/es/model/50274-iphone-holder
# https://media.printables.com/media/prints/50274/images/497759_c52263de-43bc-4b0f-bac8-36b4bfdc0e82/thumbs/cover/320x240/jpg/872dd0015427cc082d9b18a06573d902_display_large_50.webp
#  iPhone Charging Stand
# https://www.printables.com/es/model/69568-iphone-charging-stand
# https://media.printables.com/media/prints/69568/images/758929_cf24bd13-1c38-488e-b4e6-d01ede948ade/thumbs/cover/320x240/jpg/img_0021.webp
#  Iphone XR Iphone SE Passat B6 stand
# https://www.printables.com/es/model/52220-iphone-xr-iphone-se-passat-b6-stand
# https://media.printables.com/media/prints/52220/images/516024_36c88910-dcf6-420d-98bb-4d608ef20720/thumbs/cover/320x240/png/screenshot-2021-01-16-at-182241.webp
#  Elephant iPhone stand
# https://www.printables.com/es/model/249150-elephant-iphone-stand
# https://media.printables.com/media/prints/249150/images/2240957_41e80df2-6c52-47c6-80cf-308e1dcfff61/thumbs/cover/320x240/jpeg/a958dda2-d98b-40b8-b7eb-b672ae83d540_1_201_a.webp
#  iPhone Amplifier Stand
# https://www.printables.com/es/model/203839-iphone-amplifier-stand
# https://media.printables.com/media/prints/203839/images/1874763_012ddaa6-770c-4518-a229-6a5b2afbc3a5/thumbs/cover/320x240/jpg/passive_amp_environment_display_large_203839.webp
#  Iphone XR Case
# https://www.printables.com/es/model/127573-iphone-xr-case
# https://media.printables.com/media/prints/127573/images/1224603_27df4e53-459b-4157-b054-9395376241c1/thumbs/cover/320x240/jpeg/ded2de27925df94eff11f369185125a3_display_large_1.webp
#  IPhone Stand
# https://www.printables.com/es/model/145794-iphone-stand
# https://media.printables.com/media/prints/145794/images/1376884_0deab193-3efd-4adf-b654-c465409d90b4/thumbs/cover/320x240/jpg/d4035d77e192cd32342d1c872812fe22_display_large_14.webp
#  iphone stand
# https://www.printables.com/es/model/232722-iphone-stand
# https://media.printables.com/media/prints/232722/images/2512249_8ddec8ed-21e9-4595-b66c-2fb861dceeac/thumbs/cover/320x240/jpg/16643013513072122925399552418473.webp
#  Iphone 5_case
# https://www.printables.com/es/model/51752-iphone-5_case
# https://media.printables.com/media/prints/51752/images/510824_32870c82-6540-4c90-bc7c-bcb7ff1c2080/thumbs/cover/320x240/png/phone-5-case-design-basic.webp
#  iPhone Kickstand
# https://www.printables.com/es/model/80355-iphone-kickstand
# https://media.printables.com/media/prints/80355/images/862482_8355d3d7-8741-490e-9737-bd66a77516da/thumbs/cover/320x240/jpg/image1_display_large_80355.webp
#  iPhone Stand
# https://www.printables.com/es/model/100914-iphone-stand
# https://media.printables.com/media/prints/100914/images/1016695_600edb85-5b9c-4da1-8ca9-810cb0a5add5/thumbs/cover/320x240/jpg/large_display_img_2663_100914.webp
#  iPhone Microscope
# https://www.printables.com/es/model/117500-iphone-microscope
# https://media.printables.com/media/prints/117500/images/1146104_7a26aebd-12f9-4736-bfb7-887ee267e0c7/thumbs/cover/320x240/jpg/75c2ab55c8c375075c318af01a6149ff_display_large_11.webp
#  iPhone Magsafe houder
# https://www.printables.com/es/model/73074-iphone-magsafe-houder
# https://media.printables.com/media/prints/73074/images/792050_47571920-adb4-474a-a848-e162b8dfdc3d/thumbs/cover/320x240/jpg/houder-1.webp
#  Iphone Cable Organizer
# https://www.printables.com/es/model/265028-iphone-cable-organizer
# https://media.printables.com/media/prints/265028/images/2362312_2acbc119-2f55-41d1-b61c-4187c307ff43/thumbs/cover/320x240/jpeg/image-01.webp
#  MagSafe iPhone Stand
# https://www.printables.com/es/model/307406-magsafe-iphone-stand
# https://media.printables.com/media/prints/307406/images/2678732_43cf7c03-2341-4d87-aad3-fae05e6a1b38/thumbs/cover/320x240/jpg/img_0689.webp
#  Supporto IPhone
# https://www.printables.com/es/model/320021-supporto-iphone
# https://media.printables.com/media/prints/320021/images/2767789_751b8f2b-f401-4d12-af19-6c46fac07887/thumbs/cover/320x240/jpg/20221119_170216.webp
#  iPhone 8 Case
# https://www.printables.com/es/model/206916-iphone-8-case
# https://media.printables.com/media/prints/206916/images/1902693_7fa15020-803c-4eff-a4a9-885b4c6ccbd5/thumbs/cover/320x240/jpg/phone-case-thumbnail-1.webp

# %% [markdown]
# Podemos hacer varias busquedas con el mismo término a varias webs

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from time import sleep
import re

url = 'https://www.thingiverse.com/search?q='+'iphone'+'&type=things&sort=relevant'

options = webdriver.ChromeOptions()
options.add_argument('--headless')
driver = webdriver.Chrome(options=options)
driver.get(url)
sleep(5)
html = driver.page_source

soup = BeautifulSoup(html, 'html.parser')

items = soup.find_all("div",class_=re.compile("^SearchResult__searchResultItem-"))

for item in items:

    itemName = item.find("span", class_=re.compile("ThingCardHeader__cardNameWrapper"))

    print(itemName['title'])

    itemLink = item.find("a", class_=re.compile("ThingCardBody__"))

    print(itemLink['href'])

    itemImg = itemLink.find("img")

    print(itemImg['src'])
# Out:
# iphone 6 cable protector!!!!
# https://www.thingiverse.com/thing:742415
# https://cdn.thingiverse.com/renders/9c/e3/3b/9a/44/i2_preview_card.jpg
# iPhone hand
# https://www.thingiverse.com/thing:31331
# https://cdn.thingiverse.com/renders/44/bb/f6/98/b9/Hand_SUPERfinal_preview_card.jpg
# Customizable iPhone Case
# https://www.thingiverse.com/thing:40703
# https://cdn.thingiverse.com/renders/e0/c8/11/89/06/iphone_case_customizer_thumbnail_preview_card.jpg
# iPhone 6 stand
# https://www.thingiverse.com/thing:654751
# https://cdn.thingiverse.com/renders/64/bb/20/1f/6a/image_preview_card.jpg
# Bat Signal for iPhone
# https://www.thingiverse.com/thing:657146
# https://cdn.thingiverse.com/renders/9c/72/a7/05/0b/Dalpek_BatSignal_image_01_preview_card.jpg
# Moby iPhone Dock
# https://www.thingiverse.com/thing:1100768
# https://cdn.thingiverse.com/renders/59/6b/41/6d/65/Photo_Feb_26_9_54_19_AM_preview_card.jpg
# iPhone stand
# https://www.thingiverse.com/thing:938372
# https://cdn.thingiverse.com/renders/4e/7b/15/9c/27/DSC_0068_preview_card.jpg
# Iphone 6 Case (Halo Themed)
# https://www.thingiverse.com/thing:493876
# https://cdn.thingiverse.com/renders/8e/28/27/93/fd/untitled.15_preview_card.jpg
# Improved! iPhone Gear Case with Geneva Mechanism
# https://www.thingiverse.com/thing:65810
# https://cdn.thingiverse.com/renders/0d/78/34/ea/c9/8587569695_892196a58c_o_preview_card.jpg
# iPhone 6/6s stand
# https://www.thingiverse.com/thing:1289078
# https://cdn.thingiverse.com/renders/ca/02/10/5a/69/5dda00aa036678561067574e59821285_preview_card.jpg
# iPhone 6 Dock w/ Integrated Apple Watch Charging Station
# https://www.thingiverse.com/thing:880490
# https://cdn.thingiverse.com/renders/36/e2/86/27/a4/IMG_1_preview_card.JPG
# iPhone Gear Case
# https://www.thingiverse.com/thing:40190
# https://cdn.thingiverse.com/renders/3f/2d/e7/5a/c8/8340607461_f0e2569304_b_preview_card.jpg
# iPhone 6 Speaker
# https://www.thingiverse.com/thing:952783
# https://cdn.thingiverse.com/renders/2d/9e/ba/b8/ce/IMG_0194_preview_card.jpg
# GRAMiPhone - iPhone 6 Gramophone Horn
# https://www.thingiverse.com/thing:1112960
# https://cdn.thingiverse.com/renders/1d/9b/b2/b4/a0/IMG_0012_preview_card.JPG
# Customizable iPhone Stencil Case
# https://www.thingiverse.com/thing:58001
# https://cdn.thingiverse.com/renders/a8/85/dd/2f/14/Cover_preview_card.jpg
# iPhone Amp
# https://www.thingiverse.com/thing:221284
# https://cdn.thingiverse.com/renders/a6/87/18/e0/52/IMG_8092_preview_card.jpg
# iPhone 6 Plus Dock w/ Integrated Watch Charging Station
# https://www.thingiverse.com/thing:864011
# https://cdn.thingiverse.com/renders/24/7e/ea/0c/4b/_1070358_preview_card.jpg
# iPhone 5 Earbud Wrap
# https://www.thingiverse.com/thing:139033
# https://cdn.thingiverse.com/renders/6f/04/c6/dd/eb/iphone5-earbud-wrap-01_preview_card.jpg
# iPhone 6 Dock with Lightning Connector
# https://www.thingiverse.com/thing:486198
# https://cdn.thingiverse.com/renders/2c/99/7c/83/7b/iphone_3_preview_card.jpg
# Apple iPhone MagSafe Stand iPhone 12 iPhone 13 iPhone 14
# https://www.thingiverse.com/thing:4635698
# https://cdn.thingiverse.com/assets/de/d8/15/cf/eb/card_preview_IMG_1536.jpeg

# %% [markdown]
# Podemos hacer varias consultas a la vez, tratarlas y, por ejemplo, generar un documento

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from time import sleep


query = "ipad"

url = 'https://www.thingiverse.com/search?q='+query+'&type=things&sort=relevant'

url2 = 'https://www.printables.com/es/search/models?q='+query

options = webdriver.ChromeOptions()
options.add_argument('--headless')
driver = webdriver.Chrome(chrome_options=options)
driver2 = webdriver.Chrome(chrome_options=options)
driver.get(url)
driver2.get(url2)
sleep(5)
html = driver.page_source
html2 = driver2.page_source

soup = BeautifulSoup(html, 'html.parser')

searchItems = []

items = soup.find_all("div",class_=re.compile("^SearchResult__searchResultItem-"))

for item in items:

    itemName = item.find("span", class_=re.compile("ThingCardHeader__cardNameWrapper"))

    name = itemName['title']

    itemLink = item.find("a", class_=re.compile("ThingCardBody__"))

    link = itemLink['href']

    itemImg = itemLink.find("img")

    src = itemImg['src']


    searchItems.append({"name":name,"link":link,"src":src})

soup = BeautifulSoup(html2, 'html.parser')

items = soup.find_all("div",class_="result-item")

for item in items:
    itemName = item.find("a", class_="link clamp-two-lines")

    name = itemName.text

    link ='https://www.printables.com'+itemName['href']

    itemImg = item.find("div",class_="card")

    itemImg = itemImg.find('img')

    src = itemImg['src']

    searchItems.append({"name":name,"link":link,"src":src})

#print(searchItems)

html = '<!DOCTYPE html><html><head><title>Impresiones3D.com</title><link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css"><style>.card-width{width:33.33%;float:left}.card-title{overflow:hidden;text-overflow:ellipsis;white-space:nowrap}</style></head><body><div class="container-fluid"><div class="text-center"><h1>Impresiones3D.com</h1></div><nav class="navbar navbar-default"><div class="navbar-header"><a class="navbar-brand" href="#">Inicio</a></div></nav>'


for item in searchItems:
    
    html += '<div class="col-sm-3"><div class="card"><a href="'+ item['link'] +'"><img src="'+item['src']+'" class="img-responsive" alt="Card Image"><div class="card-body"><h4 class="card-title">'+ item['name'] +'</h4></div></a></div></div>'

html += '</div> </div> </body> </html>'



with open("page.html", "w", encoding="utf-8") as f:
    f.write(html)
# Out:
# C:\Users\diego\AppData\Local\Temp\ipykernel_9656\2257674183.py:14: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(chrome_options=options)
# C:\Users\diego\AppData\Local\Temp\ipykernel_9656\2257674183.py:15: DeprecationWarning: use options instead of chrome_options
#   driver2 = webdriver.Chrome(chrome_options=options)

# %% [markdown]
# Para hilar más fino, se necesita hacer más ingeniería inversa y descubrir el origen de los datos, en este caso si investigamos las peticiones de las webs podemos descubrir las peticiones POST a las webs, las cabeceras HTTP y capturar estos mensajes, por ejemplo:

# %%
import json

url = 'https://api.printables.com/graphql/'
data = {
  "operationName": "SearchPrints",
  "variables": {
    "query": "iphone",
    "categoryId": None,
    "featured": False,
    "hasMake": False,
    "competitionAwarded": False,
    "publishedDateLimitDays": None,
    "ordering": None,
    "limit": 36,
    "offset": 0
  },
  "query": "query SearchPrints($query: String, $limit: Int, $offset: Int, $categoryId: ID, $materialIds: [Int], $printerIds: [Int], $featured: Boolean, $printDuration: IntervalObject, $weight: IntervalObject, $nozzleDiameters: [Float], $filesType: [FilterPrintFilesTypeEnum], $usedMaterial: IntervalObject, $licenses: [ID], $hasMake: Boolean, $publishedDateLimitDays: Int, $competitionAwarded: Boolean, $ordering: SearchChoicesEnum) {\n  result: searchPrints(\n    query: $query\n    printType: print\n    limit: $limit\n    offset: $offset\n    categoryId: $categoryId\n    materialIds: $materialIds\n    printerIds: $printerIds\n    featured: $featured\n    printDuration: $printDuration\n    weight: $weight\n    nozzleDiameters: $nozzleDiameters\n    filesType: $filesType\n    usedMaterial: $usedMaterial\n    licenses: $licenses\n    hasMake: $hasMake\n    publishedDateLimitDays: $publishedDateLimitDays\n    competitionAwarded: $competitionAwarded\n    ordering: $ordering\n  ) {\n    items {\n      ...SearchPrintsFragment\n      __typename\n    }\n    __typename\n  }\n}\n\nfragment SearchPrintsFragment on SearchPrintType {\n  id\n  score\n  eduProject {\n    language {\n      id\n      name\n      __typename\n    }\n    __typename\n  }\n  explanation\n  image {\n    filePath\n    rotation\n    __typename\n  }\n  ratingAvg\n  ratingCount\n  filesType\n  hasModel\n  nsfw\n  name\n  ...LatestCompetitionResultSearch\n  downloadCount\n  displayCount\n  dateFeatured\n  datePublished\n  slug\n  liked\n  likesCount\n  user {\n    ...AvatarSearchFragment\n    __typename\n  }\n  __typename\n}\n\nfragment LatestCompetitionResultSearch on SearchPrintType {\n  latestCompetitionResult {\n    placement\n    competitionId\n    __typename\n  }\n  __typename\n}\n\nfragment AvatarSearchFragment on SearchUserType {\n  id\n  slug\n  publicUsername\n  company\n  verified\n  handle\n  avatarFilePath\n  badgesProfileLevel {\n    profileLevel\n    __typename\n  }\n  __typename\n}\n"
}

headers = {'Content-type': 'application/json'}

response = requests.post(url, json=data, headers=headers)

print(response.status_code)

responsejson = json.loads(response.text)

items = responsejson['data']['result']['items']

for item in items:

    print("https://www.printables.com/es/model/"+item['id']+" "+item['name'])
# Out:
# 200
# https://www.printables.com/es/model/107744 iPhone Stand / iPhone Holder
# https://www.printables.com/es/model/43469 iPhone 12 Dummy Models (iPhone 12 Mini, iPhone 12, iPhone 12 Pro, iPhone 12 Pro Max)
# https://www.printables.com/es/model/176650 iPhone Stand
# https://www.printables.com/es/model/99335 IPHONE STAND
# https://www.printables.com/es/model/157404 iPhone Stand
# https://www.printables.com/es/model/275162 iPhone SE (2020,2022) / iPhone 8
# https://www.printables.com/es/model/128413 iPhone Stand
# https://www.printables.com/es/model/267329 İphone 13
# https://www.printables.com/es/model/182712 iPhone 5 iPhone SE Case
# https://www.printables.com/es/model/253385 iPhone holder
# https://www.printables.com/es/model/267829 iPhone Holder
# https://www.printables.com/es/model/75019 iPhone XR Flexible Case (iPhone 12 wannabe)
# https://www.printables.com/es/model/106635 Iphone hand
# https://www.printables.com/es/model/131718 iPhone dock
# https://www.printables.com/es/model/99974 Iphone Vault
# https://www.printables.com/es/model/72100 iPhone Phone
# https://www.printables.com/es/model/359469 iPhone 13
# https://www.printables.com/es/model/367696 iphone xr
# https://www.printables.com/es/model/296394 iphone base
# https://www.printables.com/es/model/69568 iPhone Charging Stand
# https://www.printables.com/es/model/52220 Iphone XR Iphone SE Passat B6 stand
# https://www.printables.com/es/model/249150 Elephant iPhone stand
# https://www.printables.com/es/model/203839 iPhone Amplifier Stand
# https://www.printables.com/es/model/50274 iPhone Holder
# https://www.printables.com/es/model/127573 Iphone XR Case
# https://www.printables.com/es/model/51752 Iphone 5_case
# https://www.printables.com/es/model/145794 IPhone Stand
# https://www.printables.com/es/model/232722 iphone stand
# https://www.printables.com/es/model/80355 iPhone Kickstand
# https://www.printables.com/es/model/117500 iPhone Microscope
# https://www.printables.com/es/model/265028 Iphone Cable Organizer
# https://www.printables.com/es/model/307406 MagSafe iPhone Stand
# https://www.printables.com/es/model/100914 iPhone Stand
# https://www.printables.com/es/model/206916 iPhone 8 Case
# https://www.printables.com/es/model/320021 Supporto IPhone
# https://www.printables.com/es/model/73074 iPhone Magsafe houder

# %% [markdown]
# Las soluciones como Selenium son ineficientes y escalan mal, por lo que es conveniente intentar hilar fino y encontrar el origen de los datos.
#
# Muchas veces con buscar en las peticiones recibidas por la web desde el navegador será suficiente para encontrar el mensaje POST enviado. Otras veces no será posible y habrá que usar Selenium u otras soluciones.
#
# En este caso Thingiverse no dispone de una API libre y necesitamos una clave para hacer las peticiones.
